# %%
import pandas as pd

# %%
# import the data given for the part one.
df = pd.read_csv('mock_data_1000.csv')
df.head(10)
# Out:
#    id first_name   last_name  ...       gender  eircode                  bad_column
# 0   1    Clarice       Rubee  ...   Polygender  C15AD95                       울란바토르
# 1   2   Theodora     Stallon  ...   Non-binary  C15H6WY                 田中さんにあげて下さい
# 2   3     Revkah      Domeny  ...         Male  C15A382               `⁄€‹›ﬁﬂ‡°·‚—±
# 3   4      Talia  Trebilcock  ...      Agender  C15D407                           0
# 4   5     Revkah     Ramsier  ...     Bigender  C15R275               `⁄€‹›ﬁﬂ‡°·‚—±
# 5   6   Zebadiah    Huikerby  ...      Agender  C15WT18  הָיְתָהtestالصفحات التّحول
# 6   7      Rabbi    Simonite  ...   Polygender  C15XE30  ,。・:*:・゜’( ☻ ω ☻ )。・:*:・゜’
# 7   8       Ring      Symson  ...  Genderqueer  C15E8FT                      -$1.00
# 8   9       Chad     Olyonov  ...     Bigender  C15FK26                  社會科學院語學研究所
# 9  10  Elisabeth    McArthur  ...   Non-binary  C15VX08                         NaN
#
# [10 rows x 7 columns]

# %%
# In the below line of code I am filtering the data if id,email and eircode is null. Also, verifying the "@" in the mail and length of EIRCODE should me 7.  
df1 = df[(df['id']!="null") & (df['email']!="null") & (df['eircode']!="null") & (df['email'].str.contains("@")) & (df['eircode'].str.len()==7) ] 

# I am converting the value of id to number and non int value will be NaN. 
df1.id = pd.to_numeric(df1.id, errors='coerce')   # It will convert any non-int value to NaN

# In the last I am varifying the eircode should be Alpha-numberic. Also first-name and last-name should contain only alphabets 
df1 = df1[(df1["eircode"].str.isalnum()) & (df1["first_name"].str.isalpha()) & (df1["last_name"].str.isalpha())]

df1.head(30)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:5170: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
#     id first_name  ...  eircode                                         bad_column
# 0    1    Clarice  ...  C15AD95                                              울란바토르
# 1    2   Theodora  ...  C15H6WY                                        田中さんにあげて下さい
# 2    3     Revkah  ...  C15A382                                      `⁄€‹›ﬁﬂ‡°·‚—±
# 3    4      Talia  ...  C15D407                                                  0
# 4    5     Revkah  ...  C15R275                                      `⁄€‹›ﬁﬂ‡°·‚—±
# 5    6   Zebadiah  ...  C15WT18                         הָיְתָהtestالصفحات التّحول
# 6    7      Rabbi  ...  C15XE30                         ,。・:*:・゜’( ☻ ω ☻ )。・:*:・゜’
# 7    8       Ring  ...  C15E8FT                                             -$1.00
# 8    9       Chad  ...  C15FK26                                         社會科學院語學研究所
# 9   10  Elisabeth  ...  C15VX08                                                NaN
# 10  11     Deanna  ...  C15KC43                                       ¡™£¢∞§¶•ªº–≠
# 11  12     Bartel  ...  C15H6WY                                       Œ„´‰ˇÁ¨ˆØ∏”’
# 12  13       Didi  ...  C15FW18                                                  ᠎
# 13  14       Waly  ...  C15TP04                                         <>?:"{}|_+
# 14  15       Mort  ...  C15CY86                                                ⁰⁴⁵
# 15  16      Lotte  ...  C15YXC1                                         test⁠test‫
# 16  17    Mildrid  ...  C15V29V                                         "'"'"''''"
# 17  18        Uta  ...  C15N972  Ṱ̺̺̕o͞ ̷i̲̬͇̪͙n̝̗͕v̟̜̘̦͟o̶̙̰̠kè͚̮̺̪̹̱̤ ̖t̝͕͞...
# 18  19     Rustin  ...  C15H297                                      `⁄€‹›ﬁﬂ‡°·‚—±
# 19  20   Claudine  ...  C15YE18                                         ・(￣∀￣)・:*:
# 20  21      Lanna  ...  C15KT97                                                  ​
# 21  22    Carleen  ...  C15Y7CY                                                  ​
# 22  23    Abigail  ...  C15E8FT                                      `⁄€‹›ﬁﬂ‡°·‚—±
# 23  24    Kirstin  ...  C15WR82                                       (ﾉಥ益ಥ）ﾉ﻿ ┻━┻
# 24  25        Cal  ...  C15P681                                               -1/2
# 25  26     Culver  ...  C15E892                                                0/0
# 26  27     Porter  ...  C15P228                                                  ​
# 27  28     Bartel  ...  C15A9X3                                              $1.00
# 28  29  Salvatore  ...  C15TKP9                                 1;DROP TABLE users
# 29  30       Jeno  ...  C15RX2R                                                  ​
#
# [30 rows x 7 columns]

# %%
# And final step. Creating new CSV of Good_data as requested. It will help you to download the csv automatically :)
from google.colab import files
df1.to_csv('good_data.csv') 
files.download('good_data.csv')
